# %% [markdown]
# My first concern is finding the "apply" link on all the relevant pages. There's substantial heterogeneity in what the links look like, both visually and in the HTML.
#
# What I'm wondering is if we can come up with a selector that will correctly find the apply button on "enough" of the pages that we can just ignore the rest. Another possibility is that the links themselves are consistent enough that we can just look at all `a`s and do it based on `href` value. Let's have a look.

# %%
import pandas as pd
from lxml import html
import requests

# %%
df = pd.read_csv("dataset.csv")

# %%
# just for faster exploration
small_df = df[1:100]
small_df
full_df = df
df = small_df

# %% [markdown]
# First, we need to fetch the actual HTML of the page for each job.

# %%
resps = [requests.get(link) for link in df.link]

# %%
def has_monster_apply_button(page):
    "as opposed to an external apply button"
    maybe_btn = page.cssselect(".btn-apply")
    if maybe_btn:
        btn = maybe_btn[0]
        return bool(btn.get("href"))
    else:
        return False

# %%
df.loc[:,"page"] = [r.text for r in resps]
df.loc[:,"actual_link"] = [r.request.path_url for r in resps]
# a posting is usable if:
#  1. its part of the "v2" system on monster, which has a more standard, reasonable page structure
#  2. its not expired
#  3. its of the sort you can apply to on monster, and not an external system 
df.loc[:,"usable"] = (df["actual_link"].str.contains("v2") &
                      ~df["actual_link"].str.contains("Expired") &
                      [has_monster_apply_button(html.fromstring(p)) for p in df["page"]])

# %%
df
# Out:
#         city  applied?                                               full  \
# 2   New York         0  <article class="js_result_row" itemscope="" it...
# 3   New York         0  <article class="js_result_row" itemscope="" it...
# 4   New York         0  <article class="js_result_row" itemscope="" it...
# 5   New York         0  <article class="js_result_row" itemscope="" it...
# 6   New York         0  <article class="js_result_row" itemscope="" it...
# 7   New York         0  <article class="js_result_row" itemscope="" it...
# 8   New York         0  <article class="js_result_row" itemscope="" it...
# 9   New York         0  <article class="js_result_row" itemscope="" it...
# 10  New York         0  <article class="js_result_row" itemscope="" it...
# 11  New York         0  <article class="js_result_row" itemscope="" it...
# 12  New York         0  <article class="js_result_row" itemscope="" it...
# 13  New York         0  <article class="js_result_row" itemscope="" it...
# 14  New York         0  <article class="js_result_row" itemscope="" it...
# 15  New York         0  <article class="js_result_row" itemscope="" it...
# 16  New York         0  <article class="js_result_row" itemscope="" it...
# 17  New York         0  <article class="js_result_row" itemscope="" it...
# 18  New York         0  <article class="js_result_row" itemscope="" it...
# 19  New York         0  <article class="js_result_row" itemscope="" it...
# 20  New York         0  <article class="js_result_row" itemscope="" it...
# 21  New York         0  <article class="js_result_row" itemscope="" it...
# 22  New York         0  <article class="js_result_row" itemscope="" it...
# 23  New York         0  <article class="js_result_row" itemscope="" it...
# 24  New York         0  <article class="js_result_row" itemscope="" it...
# 25  New York         0  <article class="js_result_row" itemscope="" it...
# 26  New York         0  <article class="js_result_row" itemscope="" it...
# 27  New York         0  <article class="js_result_row" itemscope="" it...
# 28  New York         0  <article class="js_result_row" itemscope="" it...
# 29  New York         0  <article class="js_result_row" itemscope="" it...
# 30  New York         0  <article class="js_result_row" itemscope="" it...
# 31  New York         0  <article class="js_result_row" itemscope="" it...
# ..       ...       ...                                                ...
# 70  New York         0  <article class="js_result_row" itemscope="" it...
# 71  New York         0  <article class="js_result_row" itemscope="" it...
# 72  New York         0  <article class="js_result_row" itemscope="" it...
# 73  New York         0  <article class="js_result_row" itemscope="" it...
# 74  New York         0  <article class="js_result_row" itemscope="" it...
# 75  New York         0  <article class="js_result_row" itemscope="" it...
# 76  New York         0  <article class="js_result_row" itemscope="" it...
# 77  New York         0  <article class="js_result_row" itemscope="" it...
# 78  New York         0  <article class="js_result_row" itemscope="" it...
# 79  New York         0  <article class="js_result_row" itemscope="" it...
# 80  New York         0  <article class="js_result_row" itemscope="" it...
# 81  New York         0  <article class="js_result_row" itemscope="" it...
# 82  New York         0  <article class="js_result_row" itemscope="" it...
# 83  New York         0  <article class="js_result_row" itemscope="" it...
# 84  New York         0  <article class="js_result_row" itemscope="" it...
# 85  New York         0  <article class="js_result_row" itemscope="" it...
# 86  New York         0  <article class="js_result_row" itemscope="" it...
# 87  New York         0  <article class="js_result_row" itemscope="" it...
# 88  New York         0  <article class="js_result_row" itemscope="" it...
# 89  New York         0  <article class="js_result_row" itemscope="" it...
# 90  New York         0  <article class="js_result_row" itemscope="" it...
# 91  New York         0  <article class="js_result_row" itemscope="" it...
# 92  New York         0  <article class="js_result_row" itemscope="" it...
# 93  New York         0  <article class="js_result_row" itemscope="" it...
# 94  New York         0  <article class="js_result_row" itemscope="" it...
# 95  New York         0  <article class="js_result_row" itemscope="" it...
# 96  New York         0  <article class="js_result_row" itemscope="" it...
# 97  New York         0  <article class="js_result_row" itemscope="" it...
# 98  New York         0  <article class="js_result_row" itemscope="" it...
# 99  New York         0  <article class="js_result_row" itemscope="" it...
#
#            addresses                                              title  \
# 2      [1, 12, 4, 8]  \n\nSeasonal Holiday Retail Sales Jewelry Cler...
# 3     [7, 6, 12, 17]              \n\nLaboratory Clerical Associate\n\n
# 4    [0, 15, 11, 14]           \n\nTemporary Clerical professionals\n\n
# 5     [2, 6, 11, 13]  \n\nAttendance Coordinator -(Clerical) part ti...
# 6     [10, 13, 9, 1]                    \n\nOffice/Bookkeeper Clerk\n\n
# 7    [4, 17, 14, 13]                               \n\nOffice Clerk\n\n
# 8      [17, 7, 9, 8]  \n\nBD-13478 - Accounting Clerk 2 Position in ...
# 9     [2, 9, 17, 11]                             \n\nBuyer Clerical\n\n
# 10   [12, 0, 14, 13]  \n\nAdministrative/Clerical Assistant AA2136-1...
# 11    [1, 5, 15, 14]                                \n\nCourt Clerk\n\n
# 12   [15, 16, 3, 18]          \n\nAdministrative Clerk/Receptionist\n\n
# 13    [13, 4, 18, 0]  \n\nParalegal II / Criminal Clerks Unit Recept...
# 14     [3, 1, 9, 13]                  \n\nAccounts Receivable Clerk\n\n
# 15     [3, 17, 8, 2]                  \n\nAccounts Receivable Clerk\n\n
# 16   [16, 14, 12, 6]                     \n\nAccounts Payable Clerk\n\n
# 17   [3, 13, 17, 15]                     \n\nLegal Department Clerk\n\n
# 18   [10, 11, 16, 9]                           \n\nAccounting Clerk\n\n
# 19     [1, 7, 6, 11]                            \n\nStockroom Clerk\n\n
# 20    [6, 8, 11, 17]                  \n\nAccounts Receivable Clerk\n\n
# 21     [6, 17, 3, 4]                             \n\nPharmacy Clerk\n\n
# 22    [7, 1, 13, 16]                     \n\nAccounts Payable Clerk\n\n
# 23    [7, 11, 13, 5]                  \n\nACCOUNTS RECEIVABLE CLERK\n\n
# 24   [10, 5, 17, 13]                           \n\nAccounting Clerk\n\n
# 25   [4, 14, 18, 16]                     \n\nRoute Accounting Clerk\n\n
# 26    [3, 8, 15, 16]                           \n\nAccounting Clerk\n\n
# 27   [10, 0, 13, 16]                   \n\nAssistant Managing Clerk\n\n
# 28      [0, 3, 7, 2]  \n\nHealth Information Management Medical Reco...
# 29   [12, 17, 18, 8]  \n\nInvestor Services Data Entry Clerk - Cranf...
# 30   [17, 10, 0, 16]                           \n\nAccounting Clerk\n\n
# 31      [2, 6, 7, 0]                      \n\nBilling Clerk/Medical\n\n
# ..               ...                                                ...
# 70   [18, 13, 9, 14]                 \n\nFull Time Data Entry Clerk\n\n
# 71   [15, 17, 14, 3]  \n\nConstruction Plan Clerk / Assistant Estima...
# 72     [3, 8, 15, 2]                           \n\nAccounting Clerk\n\n
# 73      [9, 7, 2, 4]     \n\nManheim Skyline- Part Time Block Clerk\n\n
# 74    [10, 14, 4, 1]                             \n\nCalendar Clerk\n\n
# 75   [2, 13, 10, 15]                             \n\nShipping Clerk\n\n
# 76    [6, 8, 12, 11]                             \n\nShipping Clerk\n\n
# 77  [14, 18, 15, 10]                      \n\nMedical Records Clerk\n\n
# 78    [11, 10, 2, 8]                     \n\nAccounts Payable Clerk\n\n
# 79    [0, 10, 11, 1]                  \n\nLegal File Clerk 11-15-16\n\n
# 80    [7, 15, 16, 4]                         \n\nThrift Store Clerk\n\n
# 81      [2, 6, 3, 4]                      \n\nMedical Records Clerk\n\n
# 82    [12, 6, 0, 10]  \n\nAssistant Managing Clerk - International L...
# 83    [18, 16, 0, 9]                           \n\nAccounting Clerk\n\n
# 84    [7, 0, 13, 10]                  \n\nLegal Clerk - Immigration\n\n
# 85      [1, 9, 8, 3]                            \n\nLogistics clerk\n\n
# 86     [9, 18, 0, 6]                           \n\nData Entry Clerk\n\n
# 87     [15, 0, 1, 5]                               \n\nFloral clerk\n\n
# 88    [2, 11, 9, 14]  \n\nWarehouse Associate//Warehouse Clerk//Feed...
# 89   [9, 12, 18, 10]  \n\nCashiers & Deli Clerks Needed In Staten Is...
# 90    [2, 13, 12, 1]               \n\nFood Service - Seafood Clerk\n\n
# 91     [4, 7, 12, 6]                                 \n\nDeli Clerk\n\n
# 92    [3, 11, 15, 0]            \n\nTitle Insurance Recording Clerk\n\n
# 93      [4, 1, 3, 8]                  \n\nParalegals/ Docket Clerks\n\n
# 94      [4, 9, 3, 1]                              \n\nStock. Clerks\n\n
# 95    [4, 15, 12, 2]                \n\nAccts Payable/Accting Clerk\n\n
# 96    [8, 18, 5, 13]                   \n\nAccounts Payable / Clerk\n\n
# 97     [0, 18, 5, 2]                     \n\nPart Time Filing Clerk\n\n
# 98     [12, 1, 5, 7]                     \n\nAccounts Payable Clerk\n\n
# 99    [15, 5, 12, 0]                     \n\nAccounts Payable Clerk\n\n
#
#                                               company       resumes  \
# 2                                          \nMacys\n   [1, 3, 0, 2]
# 3                     \nSovereign Medical Services\n   [5, 2, 1, 4]
# 4                            \nCompany Confidential\n  [6, 3, 5, 1]
# 5         \nPremier Home Health Care Services, Inc\n   [5, 4, 6, 0]
# 6                              \nCiampa Management\n   [4, 3, 6, 0]
# 7                 \nInter American Cosmetics, Inc.\n   [7, 2, 0, 6]
# 8        \nPROGRAMMER RESOURCES INTERNATIONAL, INC\n   [6, 1, 3, 0]
# 9                               \nRainbow USA, Inc\n   [7, 3, 0, 6]
# 10                             \nThe Cambridge Don\n   [2, 6, 4, 5]
# 11                         \nMeridian Legal Search\n   [0, 2, 3, 6]
# 12                              \nTMI Trading Corp\n   [1, 2, 3, 0]
# 13                \nForfeiture Support Associates\n    [4, 7, 1, 3]
# 14                                 \nUS Globe Corp\n   [1, 0, 2, 7]
# 15                          \nPort Logistics Group\n   [1, 6, 2, 5]
# 16                                \nNauticus Group\n   [5, 0, 2, 1]
# 17                                 \nCaresoft Inc.\n   [4, 2, 7, 0]
# 18                            \nMedSource National\n   [0, 5, 3, 2]
# 19                               \nMercury Systems\n   [4, 3, 1, 2]
# 20                                 \nParagon Acura\n   [3, 2, 7, 0]
# 21     \nCentral Admixture Pharmacy Services, Inc.\n   [0, 4, 2, 3]
# 22                             \nMarcum Search LLC\n   [7, 6, 0, 3]
# 23                           \nTime Equities, Inc.\n   [4, 5, 1, 6]
# 24                               \nLet it Grow Inc\n   [3, 0, 2, 4]
# 25                   \nManhattan Beer Distributors\n   [3, 2, 0, 4]
# 26                           \nCatholic Cemeteries\n   [0, 6, 2, 3]
# 27                               \nNoor Associates\n   [0, 7, 3, 1]
# 28                         \nThe Floating Hospital\n   [6, 7, 0, 4]
# 29                             \nSS&C Technologies\n   [3, 4, 7, 1]
# 30                   \nHealth Plus Management, LLC\n   [0, 3, 6, 7]
# 31                                      \nTunstall\n   [2, 3, 6, 7]
# ..                                                ...           ...
# 70                             \nASAPIT Consulting\n   [6, 3, 1, 2]
# 71                 \nB. R.Fries & Associates, LLC.\n   [2, 7, 6, 4]
# 72  \nDouglaston Development (affiliate of Levine ...  [0, 7, 3, 5]
# 73                                \nCox Automotive\n   [7, 1, 3, 0]
# 74                              \nEltman Law, P.C.\n   [3, 4, 5, 7]
# 75                                  \nConfidential\n   [5, 1, 4, 0]
# 76                            \nSnow Joe + Sun Joe\n   [4, 3, 2, 7]
# 77                        \nStat Imaging Solutions\n   [6, 3, 5, 2]
# 78                                  \n451 Research\n   [4, 7, 0, 2]
# 79                             \nPark & Associates\n   [3, 4, 5, 7]
# 80                                           \nABM\n   [4, 6, 1, 5]
# 81                             \nTomkiel & Tomkiel\n   [6, 3, 2, 1]
# 82  \nNadine Bocelli & Company, Inc. - New York Le...  [5, 3, 6, 7]
# 83                                 \nThe PAR Group\n   [4, 6, 1, 3]
# 84                   \nJorge Guttlein & Associates\n   [1, 7, 2, 6]
# 85                       \nAjulia Executive Search\n   [2, 7, 1, 4]
# 86                                  \nEffy Jewelry\n   [7, 2, 6, 3]
# 87                              \nSunrise ShopRite\n   [5, 2, 7, 3]
# ..           ...                                                ...
# 70  [3, 2, 1, 0]  http://job-openings.monster.com/monster/729849...
# 71  [0, 2, 1, 3]  http://job-openings.monster.com/monster/1d8540...
# 72  [3, 1, 2, 0]  http://job-openings.monster.com/monster/a8c965...
# 73  [0, 2, 1, 3]  http://job-openings.monster.com/monster/eff1e8...
# 74  [2, 0, 1, 3]  http://job-openings.monster.com/monster/dd7931...
# 75  [2, 1, 0, 3]  http://job-openings.monster.com/monster/454a65...
# 76  [3, 1, 0, 2]  http://job-openings.monster.com/monster/448aa9...
# 77  [2, 0, 1, 3]  http://job-openings.monster.com/monster/f09f10...
# 78  [2, 0, 1, 3]  http://job-openings.monster.com/monster/abc1ef...
# 79  [2, 0, 3, 1]  http://job-openings.monster.com/monster/be9b8c...
# 80  [2, 1, 3, 0]  http://job-openings.monster.com/monster/71d2ca...
# 81  [2, 1, 0, 3]  http://job-openings.monster.com/monster/1ce9ab...
# 82  [1, 0, 2, 3]  http://job-openings.monster.com/monster/de6b90...
# 83  [3, 1, 0, 2]  http://job-openings.monster.com/monster/5c7217...
# 84  [1, 0, 2, 3]  http://job-openings.monster.com/monster/3aa036...
# 85  [0, 3, 1, 2]  http://job-openings.monster.com/monster/79db53...
# 86  [0, 1, 2, 3]  http://job-openings.monster.com/monster/0ad0d5...
# 87  [0, 2, 1, 3]  http://job-openings.monster.com/monster/35eff7...
# 88  [3, 2, 1, 0]  http://job-openings.monster.com/monster/32e362...
# 89  [3, 0, 1, 2]  http://job-openings.monster.com/monster/d07e89...
# 90  [1, 0, 3, 2]  http://job-openings.monster.com/monster/bbe7e5...
# 91  [2, 1, 0, 3]  http://job-openings.monster.com/monster/d7b575...
# 92  [1, 2, 3, 0]  http://job-openings.monster.com/monster/cb0a76...
# 93  [2, 1, 3, 0]  http://job-openings.monster.com/monster/6775be...
# 94  [1, 0, 3, 2]  http://job-openings.monster.com/monster/3f8e69...
# 95  [3, 0, 1, 2]  http://job-openings.monster.com/monster/973650...
# 96  [3, 2, 1, 0]  http://job-openings.monster.com/monster/e18dba...
# 97  [1, 2, 3, 0]  http://jobview.monster.com/part-time-filing-cl...
# 98  [1, 2, 3, 0]  http://jobview.monster.com/accounts-payable-cl...
# 99  [2, 3, 0, 1]  http://jobview.monster.com/accounts-payable-cl...
#
#                                       location     lastnames    firstnames  \
# 2                \n\n\nWayne\n        ,NJ\n\n   [1, 0, 6, 4]  [4, 6, 3, 9]
# 3          \n\n\nFair Lawn\n        ,NJ\n\n\n   [2, 6, 7, 9]  [6, 3, 7, 5]
# 4             \n\n\nBrooklyn\n        ,NY\n\n   [3, 8, 9, 4]  [0, 1, 6, 7]
# 5      \n\n\nNew York City\n        ,NY\n\n\n   [1, 4, 5, 0]  [1, 2, 0, 6]
# 6           \n\n\nFlushing\n        ,NY\n\n\n   [7, 8, 5, 3]  [0, 9, 8, 7]
# 7               \n\n\nLodi\n        ,NJ\n\n\n   [8, 0, 1, 7]  [3, 6, 9, 0]
# 8     \n\n\nFranklin Lakes\n        ,NJ\n\n\n   [1, 4, 3, 7]  [9, 3, 0, 2]
# 9           \n\n\nBrooklyn\n        ,NY\n\n\n   [7, 8, 5, 9]  [5, 7, 0, 9]
# 10       \n\n\nNew York City\n        ,NY\n\n   [8, 6, 3, 0]  [7, 2, 5, 6]
# 11     \n\n\nNew York City\n        ,NY\n\n\n   [9, 0, 6, 4]  [3, 2, 8, 4]
# 12          \n\n\nBrooklyn\n        ,NY\n\n\n   [1, 4, 9, 8]  [1, 0, 8, 7]
# 13          \n\n\nNew York\n        ,NY\n\n\n   [1, 6, 0, 9]  [3, 2, 6, 5]
# 14  \n\n\nGarden City Park\n        ,NY\n\n\n   [0, 4, 1, 6]  [3, 9, 6, 5]
# 15           \n\n\nClifton\n        ,NJ\n\n\n   [4, 8, 0, 5]  [8, 2, 3, 6]
# 16         \n\n\nSpringfield\n        ,NJ\n\n   [5, 6, 0, 7]  [6, 0, 2, 3]
# 17          \n\n\nWestwood\n        ,NJ\n\n\n   [5, 4, 1, 7]  [9, 0, 2, 6]
# 18       \n\n\nGarden City\n        ,NY\n\n\n   [0, 5, 9, 7]  [0, 9, 7, 1]
# 19       \n\n\nWest Caldwell\n        ,NJ\n\n   [3, 4, 7, 1]  [3, 8, 7, 0]
# 20          \n\n\nFlushing\n        ,NY\n\n\n   [1, 4, 9, 0]  [5, 7, 3, 9]
# 21         \n\n\nEnglewood\n        ,NJ\n\n\n   [9, 3, 4, 5]  [9, 0, 5, 7]
# 22       \n\n\nNew Hyde Park\n        ,NY\n\n   [4, 8, 1, 6]  [4, 9, 5, 1]
# 23          \n\n\nNew York\n        ,NY\n\n\n   [6, 1, 3, 8]  [1, 6, 7, 3]
# 24        \n\n\nRiver Edge\n        ,NJ\n\n\n   [5, 1, 8, 9]  [3, 5, 2, 6]
# 25            \n\n\nNew York\n        ,NY\n\n   [8, 5, 7, 2]  [6, 1, 7, 4]
# 26    \n\n\nMiddle Village\n        ,NY\n\n\n   [4, 2, 3, 6]  [8, 7, 4, 5]
# 27         \n\n\nManhattan\n        ,NY\n\n\n   [0, 5, 3, 2]  [8, 4, 3, 9]
# 28             \n\n\nBronx\n        ,NY\n\n\n   [9, 2, 1, 8]  [6, 7, 8, 5]
# 29            \n\n\nCranford\n        ,NJ\n\n   [4, 6, 7, 5]  [5, 0, 3, 1]
# 30       \n\n\nGarden City\n        ,NY\n\n\n   [4, 3, 5, 2]  [4, 2, 9, 7]
# 31  \n\n\nLong Island City\n        ,NY\n\n\n   [6, 9, 2, 5]  [6, 8, 9, 2]
# ..                                         ...           ...           ...
# 70          \n\n\nNew York\n        ,NY\n\n\n   [1, 0, 2, 6]  [3, 7, 9, 0]
# 71          \n\n\nNew York\n        ,NY\n\n\n   [1, 5, 3, 9]  [7, 2, 9, 5]
# 72        \n\n\nDouglaston\n        ,NY\n\n\n   [7, 6, 3, 5]  [8, 2, 4, 5]
# 73         \n\n\nFairfield\n        ,NJ\n\n\n   [3, 9, 8, 2]  [6, 5, 8, 9]
# 74       \n\n\nJersey City\n        ,NJ\n\n\n   [9, 8, 0, 5]  [2, 1, 9, 3]
# 75            \n\n\nEdison\n        ,NJ\n\n\n   [8, 2, 1, 3]  [4, 6, 0, 3]
# 76         \n\n\nCarlstadt\n        ,NJ\n\n\n   [2, 0, 3, 4]  [4, 5, 8, 0]
# 77        \n\n\nHackensack\n        ,NJ\n\n\n   [0, 4, 3, 5]  [6, 9, 8, 4]
# 78          \n\n\nNew York\n        ,NY\n\n\n   [3, 7, 4, 2]  [3, 6, 8, 7]
# 79      \n\n\nFlorham Park\n        ,NJ\n\n\n   [4, 9, 5, 2]  [1, 5, 4, 9]
# 80            \n\n\nQueens\n        ,NY\n\n\n   [6, 9, 8, 5]  [7, 4, 1, 5]
# 81         \n\n\nScarsdale\n        ,NY\n\n\n   [5, 4, 0, 8]  [3, 8, 2, 1]
# 82          \n\n\nNew York\n        ,NY\n\n\n   [9, 8, 5, 3]  [6, 2, 7, 8]
# 83          \n\n\nLynbrook\n        ,NY\n\n\n   [9, 2, 7, 6]  [5, 2, 7, 0]
# 84          \n\n\nNew York\n        ,NY\n\n\n   [2, 7, 6, 1]  [4, 1, 8, 6]
# 85     \n\n\nScotch Plains\n        ,NJ\n\n\n   [8, 5, 0, 1]  [1, 8, 0, 5]
# 86          \n\n\nNew York\n        ,NY\n\n\n   [2, 9, 4, 0]  [6, 8, 1, 3]
# 87     \n\n\nWest Caldwell\n        ,NJ\n\n\n   [0, 9, 2, 5]  [4, 7, 8, 5]
# 88      \n\n\nSaddle Brook\n        ,NJ\n\n\n   [2, 1, 0, 4]  [2, 7, 5, 6]
# 89          \n\n\nNew York\n        ,NY\n\n\n   [0, 6, 2, 8]  [2, 8, 5, 7]
# 90            \n\n\nFort Lee\n        ,NJ\n\n   [1, 4, 9, 5]  [4, 1, 0, 7]
# 91            \n\n\nQueens\n        ,NY\n\n\n   [4, 7, 8, 6]  [1, 5, 2, 4]
# 92           \n\n\nBayside\n        ,NY\n\n\n   [6, 8, 5, 0]  [8, 3, 5, 0]
# 93          \n\n\nNew York\n        ,NY\n\n\n   [6, 5, 2, 7]  [2, 6, 3, 4]
# 94          \n\n\nNew York\n        ,NY\n\n\n   [7, 0, 3, 2]  [3, 0, 9, 2]
# 95           \n\n\nYonkers\n        ,NY\n\n\n   [8, 7, 1, 5]  [7, 2, 9, 1]
# 96          \n\n\nBrooklyn\n        ,NY\n\n\n   [4, 9, 3, 2]  [3, 7, 0, 9]
# 97       \n\n\nCedar Grove\n        ,NJ\n\n\n   [6, 3, 0, 1]  [1, 9, 3, 8]
# 98            \n\n\nRoseland\n        ,NJ\n\n   [3, 6, 2, 9]  [3, 5, 2, 1]
# 99       \n\n\nGarden City\n        ,NY\n\n\n   [6, 3, 2, 8]  [6, 7, 1, 2]
#
#         type                                      original_link  \
# 2   clerical  http://jobview.monster.com/seasonal-holiday-re...
# 3   clerical  http://jobview.monster.com/laboratory-clerical...
# 4   clerical  http://jobview.monster.com/temporary-clerical-...
# 5   clerical  http://jobview.monster.com/attendance-coordina...
# 6   clerical  http://jobview.monster.com/office-bookkeeper-c...
# 7   clerical  http://jobview.monster.com/office-clerk-job-lo...
# 8   clerical  http://jobview.monster.com/bd-13478-accounting...
#
#            zipcodes                                        actual_link  \
# 2   [10, 3, 13, 11]  /seasonal-holiday-retail-sales-jewelry-clerica...
# 3    [14, 10, 0, 1]                       /v2/job/View?JobID=174742599
# 4    [13, 12, 8, 0]                       /v2/job/View?JobID=173095192
# 5    [7, 16, 2, 12]                       /v2/job/View?JobID=175551323
# 6      [2, 4, 6, 7]                       /v2/job/View?JobID=175927606
# 7    [18, 14, 0, 3]                       /v2/job/View?JobID=172842490
# 8    [13, 6, 12, 9]                       /v2/job/View?JobID=175740073
# 9    [2, 10, 6, 16]                       /v2/job/View?JobID=175788974
# 10    [7, 4, 9, 10]                    /v2/job/Expired?JobID=175391943
# 11   [5, 0, 17, 13]                       /v2/job/View?JobID=174845421
# 12  [16, 8, 13, 14]                       /v2/job/View?JobID=170347801
# 13    [8, 1, 5, 10]  /paralegal-ii-criminal-clerks-unit-receptionis...
# 14  [12, 11, 17, 1]                       /v2/job/View?JobID=168708790
# 15  [13, 11, 6, 17]  /accounts-receivable-clerk-job-clifton-nj-us-1...
# 16   [17, 4, 8, 14]                       /v2/job/View?JobID=112321888
# 17    [8, 2, 14, 3]                       /v2/job/View?JobID=174897132
# 18  [3, 18, 15, 12]                       /v2/job/View?JobID=157958403
# 19    [13, 3, 4, 6]                       /v2/job/View?JobID=174086400
# 20  [14, 3, 11, 17]                       /v2/job/View?JobID=174890890
# 21    [14, 6, 4, 2]                       /v2/job/View?JobID=175904267
# 22   [17, 14, 3, 9]                       /v2/job/View?JobID=175996032
# 23    [4, 5, 3, 10]                       /v2/job/View?JobID=175451036
# 24   [18, 5, 13, 0]                       /v2/job/View?JobID=173537873
# 25    [5, 3, 12, 9]                       /v2/job/View?JobID=174846977
# 26   [12, 7, 9, 14]                       /v2/job/View?JobID=175328613
# 27     [7, 0, 2, 8]                    /v2/job/Expired?JobID=174342201
# 28   [10, 16, 2, 3]  /health-information-management-medical-records...
# 29    [5, 16, 8, 1]                       /v2/job/View?JobID=176265548
# 30  [10, 12, 1, 18]                       /v2/job/View?JobID=173968804
# 31  [1, 15, 12, 11]                       /v2/job/View?JobID=176031202
# ..              ...                                                ...
# 70    [9, 14, 5, 1]  /jobs/asapit-consulting-06c667cf/full-time-dat...
# 71  [15, 12, 10, 1]  /jobs/b-r-fries-associates-llc-fa3bc1d8/constr...
# 72    [10, 4, 7, 3]  /jobs/douglaston-development-affiliate-of-levi...
# 73   [7, 6, 14, 17]                   /jobs/search?id=363080711&fjda=1
# 74   [3, 18, 16, 7]  /jobs/eltman-law-p-c-16e0abfe/calendar-clerk-7...
# 75  [10, 18, 12, 5]  /jobs/confidential-26c7b262/shipping-clerk-4a9...
# 76   [13, 16, 2, 5]  /jobs/snow-joe-sun-joe-11d8d030/shipping-clerk...
# 77   [2, 10, 14, 5]  /jobs/search?id=392472991&aff=FCE5C16E-79AD-4B...
# 78  [3, 16, 14, 15]  /jobs/451-research-26d07c00/accounts-payable-c...
# 79   [0, 18, 1, 17]  /jobs/park-associates-fadf9391/legal-file-cler...
# 80    [17, 5, 8, 9]  /jobs/abm-e74c2180/thrift-store-clerk-caf56e63...
# 81    [3, 5, 11, 7]  /jobs/tomkiel-tomkiel-73497cc8/medical-records...
# 82   [4, 12, 7, 14]  /jobs/nadine-bocelli-company-inc-new-york-lega...
# 83   [15, 0, 6, 16]  /jobs/search?id=392475422&aff=3B0C86C8-A880-45...
# 84    [8, 11, 2, 0]  /jobs/jorge-guttlein-associates-74d2c55f/legal...
# 85  [18, 13, 10, 4]  /jobs/ajulia-executive-search-917f64c5/logisti...
# 86   [10, 15, 1, 7]  /jobs/effy-jewelry-f2cc2cec/data-entry-clerk-9...
# 87    [7, 1, 10, 6]  /jobs/sunrise-shoprite-6225b8d3/floral-clerk-1...
# 88    [3, 13, 4, 0]  /jobs/22nd-century-staffing-inc-tscsi-1a5a31a5...
# 89   [6, 17, 14, 2]  /jobs/cactus-holdings-inc-f85037c6/cashiers-de...
# 90  [10, 13, 2, 18]  /jobs/cafassos-fairway-market-3f1bebf4/food-se...
# 91  [18, 2, 11, 13]  /jobs/dursos-pasta-ravioli-d9c0d882/deli-clerk...
# 92    [7, 10, 6, 0]  /jobs/jobtracks-5fe1668b/title-insurance-recor...
# 93   [8, 11, 16, 4]  /jobs/the-metropolitan-companies-long-island-6...
# 94   [8, 18, 16, 3]  /jobs/the-genard-group-inc-847b3f71/stock-cler...
# 95    [8, 5, 7, 18]  /jobs/ecco-iii-enterprises-inc-0debae35/accts-...
# 96    [6, 17, 4, 7]          /wisquickregapply.asp?idx=204804&ref=1531
# 97    [7, 8, 3, 10]                       /v2/job/View?JobID=174849078
# 98  [18, 11, 12, 6]                       /v2/job/View?JobID=120780388
# 99  [15, 11, 4, 13]                       /v2/job/View?JobID=173968857
#
#                                                  page usable
# 2   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...  False
# 3   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...  False
# 4   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 5   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 6   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 7   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 8   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 9   <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 10  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...  False
# 11  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 12  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 13  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...  False
# 14  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 15  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...  False
# 16  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 17  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 18  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 19  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...  False
# 20  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 21  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...  False
# 22  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 23  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 24  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 25  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 26  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 27  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...  False
# 28  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...  False
# 29  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 30  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 31  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# ..                                                ...    ...
# 70  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 71  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 72  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 73  \r\n<!DOCTYPE html>\r\n<html lang="en" ng-app=...  False
# 74  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 75  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 76  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 77  \r\n<!DOCTYPE html>\r\n<html lang="en" ng-app=...  False
# 78  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 79  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 80  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 81  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 82  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 83  \r\n<!DOCTYPE html>\r\n<html lang="en" ng-app=...  False
# 84  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 85  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 86  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 87  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 88  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 89  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 90  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 91  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 92  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 93  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 94  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 95  <!doctype html>\n<!--[if lt IE 7]>      <html ...  False
# 96  <!DOCTYPE HTML>\r\n<html>\r\n<head>\r\n\r\n   ...  False
# 97  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 98  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
# 99  <!DOCTYPE html>\r\n\r\n\r\n\r\n<html>\r\n<head...   True
#
# [98 rows x 18 columns]

# %% [markdown]
# Let's try to get applying to a single posting working

# %%
import requests
from requests import Request, Session
import re

# probably should start using this eventually to avoid detection
FIREFOX_USER_AGENT = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:16.0.1) Gecko/20121011 Firefox/21.0.1'

# %%
base_url = "http://jobview.monster.com"
path = "/v2/job/View?JobID=112321888"
url = base_url + re.sub("View", "Apply", path)
url
# Out:
# 'http://jobview.monster.com/v2/job/Apply?JobID=112321888'

# %%
s = Session()
s.headers.update({'User-Agent': FIREFOX_USER_AGENT})
resp = s.get(url)

# %%
# extract the verification token that monster uses to validate the request
page = html.fromstring(resp.text)
hidden_token_input = page.cssselect('input[name="__RequestVerificationToken"]')[0]
verif_token = hidden_token_input.value

# %%
# first we need to submit a resume
submit_url = "http://jobview.monster.com/v2/apply/Upload"
files = {"Attachments": ('testing.pdf', open('testing.pdf', 'rb'), 'application/pdf', {})}
req = Request('POST', submit_url, files=files)
preped = req.prepare()
print preped.body
# Out:
# --759648a209d14d33a1bb02178f00da57
# Content-Disposition: form-data; name="Attachments"; filename="testing.pdf"
# Content-Type: application/pdf
#
# %PDF-1.3
# %���������
# 4 0 obj
# << /Length 5 0 R /Filter /FlateDecode >>
# stream
# ��8he �W"��F�E������|Ņ���;J
# endstream
# endobj
# 5 0 obj
# 169
# endobj
# 2 0 obj
# << /Type /Page /Parent 3 0 R /Resources 6 0 R /Contents 4 0 R /MediaBox [0 0 612 792]
# >>
# endobj
# 6 0 obj
# << /ProcSet [ /PDF /Text ] /ColorSpace << /Cs1 7 0 R >> /Font << /TT1 8 0 R
# >> >>
# endobj
# 9 0 obj
# << /Length 10 0 R /N 3 /Alternate /DeviceRGB /Filter /FlateDecode >>
# stream
# x��wTS��Ͻ7��" %�z	 �;HQ�I�P��&vDF)VdT�G�"cE��b�	�P��QDE�݌k	�5�ޚ��Y�����g�}׺P���tX�4�X���\���X��ffG�D���=���HƳ��.�d��,�P&s���"7C$
# ��9�r��9h�x�g��Ib�טi���f��S�b1+��M�xL���0��o�E%Ym�h����Y��h����~S�=�z�U�&�ϞA��Y�l�/��$Z����U�m@��O� ��ޜ��l^���'���ls�k.+�7���oʿ�9�����V;�?�#I3eE妧�KD����d�����9i���,�����UQ�	��h��<�X�.d
# ���6'~�khu_}�9P�I�o=C#$n?z}�[1
# Ⱦ�h���s�2z���\�n�LA"S���dr%�,�߄l��t�
# �3p� ��H�.Hi@�A>�
# p�G@
# �&�x�*���s�b|!�
# Σ��-r�q�r�.d.�_xp��Uە�Z���M׍�v�m���=����+K�G�ǔ����^���W�W����b�j�>:>�>�>�v��}/�a��v���������O8�	�
# �FV>2	u�����/�_$\�B�Cv�<	5]�s.,4�&�y�Ux~xw-bEDCĻH����G��KwF�G�E�GME{E�EK�X,Y��F�Z� �={$vr����K����
# w����X�bY^�Ю�]�����W�Va[q`i�d��2���J�jGէ������{�����׿�m���>���Pk�Am�a�����꺿g_D�H��G�G��u�;��7�7�6�Ʊ�q�o���C{��P3���8!9�����<�y�}��'�����Z�Z���։��6i{L{��ӝ�-?��|������gKϑ���9�w~�Bƅ��:Wt>���ҝ����ˁ��^�r�۽��U��g�9];}�}��������_�~i��m��p���㭎�}��]�/���}������.�{�^�=�}����^?�z8�h�c��'
# O*��?�����f�����`ϳ�g���C/����O�ϩ�+F�F�G�Gό���z����ˌ��ㅿ)����ѫ�~w��gb���k��?Jި�9���m�d���wi獵�ޫ�?�����c�Ǒ��O�O���?w|	��x&mf������
# �d;�9���#��H)��XRB�M^�
# ��X�G+�K�%Y����0I1�bM�DY�`Ve��y+��peS�s�e�p\��N�.	fSR"O�Ä���CΫ]�=v��き�:?��r�dj������w��N������Oq����;{�-�4\ESӫ���͖9m7�WN�*ҭ	������y�)�ߤ�yJ����c���z|�)�\LbI��k�6�m<-��Yo��y��/'Z���¢5#+mc�@���F='�[��)ю�n���o�Y���B�XX�����ns^l����Y;g�Vv��;ۆ�	1�ڢQ�[D��M���_�V<�G�i0�?�D���S��|̂�Je�'�D�T���j�'Oɨj]����>�5Q�\�ɏ4i��o�;<��,���<��6ҹ�ȅ<���c�1r��`�<s��<�U�/�o#�6F�c��)��"�
# endstream
# endobj
# 14 0 obj
# 4918
# endobj
# 15 0 obj
# (testing)
# endobj
# 16 0 obj
# (Mac OS X 10.11.6 Quartz PDFContext)
# endobj
# 17 0 obj
# (Pages)
# endobj
# 18 0 obj
# (D:20161126201909Z00'00')
# endobj
# 1 0 obj
# << /Title 15 0 R /Producer 16 0 R /Creator 17 0 R /CreationDate 18 0 R /ModDate
# 18 0 R >>
# endobj
# xref
# 0 19
# 0000000000 65535 f
# 0000009175 00000 n
# 0000000284 00000 n
# 0000003255 00000 n
# 0000000022 00000 n
# 0000000265 00000 n
# 0000000388 00000 n
# 0000003220 00000 n
# 0000003388 00000 n
# 0000000485 00000 n
# 0000003199 00000 n
# 0000003338 00000 n
# 0000003751 00000 n
# 0000004001 00000 n
# 0000009009 00000 n
# 0000009030 00000 n
# 0000009056 00000 n
# 0000009109 00000 n
# 0000009133 00000 n
# trailer
# << /Size 19 /Root 11 0 R /Info 1 0 R /ID [ <42847f941ae678331942090e3b6291b7>
# <42847f941ae678331942090e3b6291b7> ] >>
# startxref
# 9280
# %%EOF
#
# --759648a209d14d33a1bb02178f00da57--

# %%
resp = s.send(preped)
assert resp.ok
resume_json = resp.json()
print resume_json
resume_ref = resume_json["rValue"]
# Out:
# {u'title': u'testing.pdf', u'rValue': u'EAAQ3l7skbh_LLx.wARpxf1.JVkQsLP6wj0z.iK2Ou1XRhERILM8NXm1FZpN_fUiFDjcTcJnstf9NlSGX6X_0fHXpA--', u'success': True, u'dateTime': u'11/26/2016'}

# %% [markdown]
# Now that we've submitted a resume, we need to take that id and use it in submitting an actual application

# %%
# the url to POST to to apply is the same one to GET to view the application form
# NOTE we will eventually need to add detection and handling for the mandatory
# "diversity candidate" thingy section that appears in some applications
data = {
    "__RequestVerificationToken": verif_token,
    "Pi.FirstName": "Foo",
    "Pi.LastName": "Bar",
    "Pi.CareerLevelId": "12",
    "Pi.EducationLevelId": "5",
    "Pi.EmailAddress": "monstertesting4@jamesporter.me",
    "Pi.CountryId": "164",
    "Pi.UserEnteredGeoName": "14001, Akron, NY",
    "Pi.UserEnteredGeoNameTranslated": "14001, Akron, NY",
    "Pi.RefGeoId": "7179994",
    "Pi.WorkAuthorizationStatus": "1",
    "Pi.IsInEditMode": "true",
    "Rs.ResumeValue": resume_ref,
    "Rs.SearchableMember": "false",
    "Rs.DiversityMember": "false",
    "rs.TmpResumes[0].FilePath": resume_ref,
    "rs.TmpResumes[0].Title": "testing.pdf",
    "rs.TmpResumes[0].IsPublic": "false",
    "rs.TmpResumes[0].IsDiversityActive": "false",
    "CoverLetter.CoverLetterBody": "",
    "CoverLetter.SaveCoverLetter": "false",
    "CoverLetter.CoverLetterTitle": "",
}

form_data = [(key, (None, val)) for key, val in data.iteritems()]
form_data.append(("Attachments", ("", "", "application/octet-stream")))
req = Request(
    "POST", url,
    files=form_data
)
preped = req.prepare()
# do a bit of finagling to the body
print preped.body
# Out:
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.CareerLevelId"
#
# 12
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="CoverLetter.SaveCoverLetter"
#
# false
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.WorkAuthorizationStatus"
#
# 1
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="rs.TmpResumes[0].Title"
#
# testing.pdf
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Rs.SearchableMember"
#
# false
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="CoverLetter.CoverLetterTitle"
#
#
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Rs.DiversityMember"
#
# false
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="__RequestVerificationToken"
#
# j7SDYYfF_sosoSsCXPMbIIB_0KUwzwSdKo9ah9q6wvzkumeOcq36weoH9Uw5b5bC9MVyX5wexnIbvwNOZXYJa6-SSFY3686kBfnAaBkc6kOsl0A75NOAs2FM59Y1
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.CountryId"
#
# 164
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.FirstName"
#
# Foo
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="rs.TmpResumes[0].FilePath"
#
# EAAQ3l7skbh_LLx.wARpxf1.JVkQsLP6wj0z.iK2Ou1XRhERILM8NXm1FZpN_fUiFDjcTcJnstf9NlSGX6X_0fHXpA--
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Rs.ResumeValue"
#
# EAAQ3l7skbh_LLx.wARpxf1.JVkQsLP6wj0z.iK2Ou1XRhERILM8NXm1FZpN_fUiFDjcTcJnstf9NlSGX6X_0fHXpA--
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="rs.TmpResumes[0].IsPublic"
#
# false
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.UserEnteredGeoName"
#
# 14001, Akron, NY
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.RefGeoId"
#
# 7179994
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.UserEnteredGeoNameTranslated"
#
# 14001, Akron, NY
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="CoverLetter.CoverLetterBody"
#
#
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.IsInEditMode"
#
# true
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="rs.TmpResumes[0].IsDiversityActive"
#
# false
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.EmailAddress"
#
# monstertesting4@jamesporter.me
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.EducationLevelId"
#
# 5
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Pi.LastName"
#
# Bar
# --f4bb51f5c46d48c786795f87e0894b4d
# Content-Disposition: form-data; name="Attachments"; filename=""
# Content-Type: application/octet-stream
#
#
# --f4bb51f5c46d48c786795f87e0894b4d--

# %%
resp = s.send(preped)

# %%
s.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='ApplyCtx', value='1=112321888&28=2&29=4509&35=Accounts+Payable+Clerk&48=&49=&59=&50=&51=Springfield%2c+NJ&52=Nauticus+Group&56=&65=121279623&69=1_0_0&72=JSON&73=0&77=False', port=None, port_specified=False, domain='.monster.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='__RequestVerificationToken_L3Yy0', value='tu9ik5eX-ytLuewMsBELCkXJ_o9oc-HhAF8PYbVL5pTpk548wKCOShXFmtM1Ezkqv0YOlPrwtiyHyrFowV2Yh5jUiKsNcWYY-MylDqWZWy9YknHV_QNhKPTKejo1', port=None, port_specified=False, domain='jobview.monster.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='atmResolver', value='|Seeker|jobview|58|164|', port=None, port_specified=False, domain='jobview.monster.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)]>
